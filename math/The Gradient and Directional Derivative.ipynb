# %% [markdown]
# *A draft notebook from my Calculus II files.*
# <hr>

# %%
from sympy import *

# %%
init_printing()

# %% [markdown]
# # The Gradient
#
# [Video](https://www.khanacademy.org/math/multivariable-calculus/multivariable-derivatives/modal/v/gradient).

# %% [markdown]
# Consider:
#
# $$ f(x, y) = x^2 \sin{y}$$

# %%
x, y = symbols('x y')

# %%
f = x**2 * sin(y)

# %% [markdown]
# ## Compute partial derivatives

# %%
dx = diff(f, x)
dx
# Out:
# 2⋅x⋅sin(y)

# %%
dy = diff(f, y)
dy
# Out:
#  2
# x ⋅cos(y)

# %% [markdown]
# ## Nabla $\nabla$, "the  gradient"

# %% [markdown]
# Also pronounced "del".
#
# The gradient of $f$ is a vector that has all the partial derivatives in it.
#
# In this case, $f$ is a two-variable function so there are two derivatives in it.
#
# \begin{align}
#     \nabla f &= \left[ \frac{f_x}{f_y} \right] \\ \\
#     &= \left[ \frac{ 2x \sin{y} }{ x^2 \cos{y} } \right]
# \end{align}

# %% [markdown]
# # Direction of steepest ascent

# %% [markdown]
# The [gradient points in the direction of steepest ascent](https://www.khanacademy.org/math/multivariable-calculus/multivariable-derivatives/modal/v/gradient-and-graphs). Not 100% sure what this means...

# %% [markdown]
# ## New function $g$
#
# To match the example in the video linked above.

# %%
g = x**2 + y**2
g
# Out:
#  2    2
# x  + y

# %%
g = plotting.plot3d(g, (x, -5, 5), (y, -5, 5))

# %% [markdown]
# ## $ \nabla g $

# %%
gradient = [
    diff(g, x),
    diff(g, y)
]

gradient
# Out:
# [2⋅x, 2⋅y]

# %% [markdown]
# The gradient is a function that takes in an $(x, y)$ input and returns a vector. Perhaps this vector points in the direction of steepest ascent?

# %% [markdown]
# ## Direction of steepest ascent at $(1, 1)$

# %%
p1 = {'x': 1, 'y': 1}

# %%
delAtP1 = [d.subs(p1) for d in gradient]
delAtP1
# Out:
# [2, 2]

# %% [markdown]
# I think this means that if you are standing at $(1, 1, 2)$, you should "walk" in the $(2, 2)$ direction in order to reach a higher output value (since this is the fastest way). I don't really understand what this means.
#
# <img src='attachment:gradient.png' style='width: 700px'>

# %% [markdown]
# Link to [GeoGebra](https://www.geogebra.org/3d/acaf4ktd).

# %% [markdown]
# # Directional derivative
#
# Link [to video](https://www.khanacademy.org/math/multivariable-calculus/multivariable-derivatives/modal/v/directional-derivative).
